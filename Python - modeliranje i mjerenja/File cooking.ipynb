# %%
file1 = open('ozone_sunset1.csv','r+')
file2 = open('el_sunset1.txt','w')
file3 = open('ozone_sunset1.txt', 'w')
file3.close()
file2.close()

lines = file1.readlines()
for line in lines:
    #line=line.split('\n')[0]
    if "El"==line[0:2]:
        file2 = open('el_sunset1.txt','a')
        file2.write(line)
        file2.close()
    else:
        file3 = open('ozone_sunset1.txt', 'a')
        file3.write(line)
        file3.close()
