# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from astropy.io import ascii

# %%
meanV1_1, stdV1_1, meanV2_1, stdV2_1, el_1 = np.loadtxt('MjerenjaLosinj1.txt', delimiter=",",
                                                  dtype = 'float', unpack=True,skiprows=2, usecols=[0,1,2,3,5])

meanV1_2, stdV1_2, meanV2_2, stdV2_2, el_2 = np.loadtxt('MjerenjaLosinj2.txt', delimiter=",",
                                                  dtype = 'float', unpack=True,skiprows=3, usecols=[0,1,2,3,5])

meanV1_3, stdV1_3, meanV2_3, stdV2_3, el_3 = np.loadtxt('MjerenjaLosinj3.txt', delimiter=",",
                                                  dtype = 'float', unpack=True,skiprows=4, usecols=[0,1,2,3,5])

meanV1_4, stdV1_4, meanV2_4, stdV2_4, el_4 = np.loadtxt('MjerenjaLosinj4.txt', delimiter=",",
                                                  dtype = 'float', unpack=True,skiprows=2, usecols=[0,1,2,3,5])

fig, ax = plt.subplots(4,1,figsize=(10,25))
#ax[2].plot(el_3, meanV1_3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu prvog kanala')
#ax[2].plot(el_3, meanV2_3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu drugog kanala')
ax[2].errorbar(el_3, meanV1_3,stdV1_3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu prvog kanala')
ax[2].errorbar(el_3, meanV2_3,stdV2_3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu drugog kanala')
ax[2].set(xlabel='Elevacija', ylabel='Napon [V]',title='Day 3')
ax[2].grid( which='major', color='#666666', linestyle='-')
ax[2].grid(which='minor', color='silver', linestyle='--')
ax[2].legend(loc='best')
ax[2].minorticks_on()
ax[0].errorbar(el_1, meanV1_1,stdV1_1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu prvog kanala')
ax[0].errorbar(el_1, meanV2_1,stdV2_1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu drugog kanala')
ax[0].set(xlabel='Elevacija', ylabel='Napon [V]',title='Day 1')
ax[0].grid( which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].legend(loc='best')
ax[0].minorticks_on()
ax[1].errorbar(el_2, meanV1_2,stdV1_2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu prvog kanala')
ax[1].errorbar(el_2, meanV2_2,stdV2_2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu drugog kanala')
ax[1].set(xlabel='Elevacija', ylabel='Napon [V]',title='Day 2')
ax[1].grid( which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].legend(loc='best')
ax[1].minorticks_on()
ax[3].errorbar(el_4, meanV1_4,stdV1_4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu prvog kanala')
ax[3].errorbar(el_4, meanV2_4,stdV2_4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu drugog kanala')
ax[3].set(xlabel='Elevacija', ylabel='Napon [V]',title='Day 4')
ax[3].grid( which='major', color='#666666', linestyle='-')
ax[3].grid(which='minor', color='silver', linestyle='--')
ax[3].legend(loc='best')
ax[3].minorticks_on()
plt.show()
plt.close(fig)

print(np.mean(stdV1_1/meanV1_1)*100, "% ", np.mean(stdV2_1/meanV2_1)*100, "%")
print(np.mean(stdV1_2/meanV1_2)*100, "% ", np.mean(stdV2_2/meanV2_2)*100, "%")
print(np.mean(stdV1_3/meanV1_3)*100, "% ", np.mean(stdV2_3/meanV2_3)*100, "%")
print(np.mean(stdV1_4/meanV1_4)*100, "% ", np.mean(stdV2_4/meanV2_4)*100, "%")

meanV1_3[:30]
# Out:
# 54.257144580072634 %  45.88884639016905 %
# 22.60734559627187 %  21.03418737029874 %
# 31.05684118112152 %  31.96487358952599 %
# 35.88515486358058 %  35.81304261259879 %
# array([1.243, 4.34 , 1.252, 4.382, 1.236, 4.329, 1.246, 4.409, 1.246,
#        4.416, 1.275, 4.492, 1.272, 4.469, 1.27 , 4.49 , 1.297, 4.537,
#        1.295, 4.512, 1.279, 4.495, 1.28 , 4.606, 1.326, 4.576, 1.321,
#        4.547, 1.309, 4.583])

# %%
meanV1, stdV1, meanV2, stdV2, el = np.loadtxt('MjerenjaLosinj1.txt', delimiter=",",
                                              dtype = 'float', unpack=True,skiprows=2, usecols=[0,1,2,3,5])

v1_310 = meanV1[::2]
v1_320 = meanV1[1::2]
v2_310 = meanV2[1::2]
v2_320 = meanV2[::2]

std_v1_310 = stdV1[::2]
std_v1_320 = stdV1[1::2]
std_v2_310 = stdV2[1::2]
std_v2_320 = stdV2[::2]

ratio1 = v1_310 / v1_320
std_r1 = ratio1 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v1_320**2)/(v1_320**2))
ratio2 = v2_310 / v2_320
std_r2 = ratio2 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v2_320**2)/(v2_320**2))
ratio3 = v1_310 / v2_320
std_r3 = ratio3 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v2_320**2)/(v2_320**2))
ratio4 = v2_310 / v1_320
std_r4 = ratio4 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v1_320**2)/(v1_320**2))

el_even = el[::2]
el_odd = el[1::2]

fig, ax = plt.subplots(2, 1, figsize=(10,10))
ax[0].errorbar(90-el_even, ratio1, std_r1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[0].errorbar(90-el_odd, ratio2, std_r2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[0].errorbar(90-el_even, ratio3, std_r3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[0].errorbar(90-el_odd, ratio4, std_r4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[0].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona',title='Day 1')
ax[0].grid( which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].legend(loc='best')
ax[0].minorticks_on()
ax[1].plot(90-el_even, ratio1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[1].plot(90-el_odd, ratio2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[1].plot(90-el_even, ratio3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[1].plot(90-el_odd, ratio4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[1].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona')
ax[1].grid( which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].legend(loc='best')
ax[1].minorticks_on()
plt.show()
plt.close(fig)

# %%
meanV1, stdV1, meanV2, stdV2, el = np.loadtxt('MjerenjaLosinj2.txt', delimiter=",",
                                              dtype = 'float', unpack=True,skiprows=3, usecols=[0,1,2,3,5])

v1_310 = meanV1[:-1:2]
v1_320 = meanV1[1:-1:2]
v2_310 = meanV2[1:-1:2]
v2_320 = meanV2[:-1:2]

std_v1_310 = stdV1[:-1:2]
std_v1_320 = stdV1[1:-1:2]
std_v2_310 = stdV2[1:-1:2]
std_v2_320 = stdV2[:-1:2]

ratio1 = v1_310 / v1_320
std_r1 = ratio1 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v1_320**2)/(v1_320**2))
ratio2 = v2_310 / v2_320
std_r2 = ratio2 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v2_320**2)/(v2_320**2))
ratio3 = v1_310 / v2_320
std_r3 = ratio3 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v2_320**2)/(v2_320**2))
ratio4 = v2_310 / v1_320
std_r4 = ratio4 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v1_320**2)/(v1_320**2))

el_even = el[:-1:2]
el_odd = el[1:-1:2]

fig, ax = plt.subplots(2, 1, figsize=(10,10))
ax[0].errorbar(90-el_even, ratio1, std_r1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[0].errorbar(90-el_odd, ratio2, std_r2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[0].errorbar(90-el_even, ratio3, std_r3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[0].errorbar(90-el_odd, ratio4, std_r4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[0].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona',title='Day 2')
ax[0].grid( which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].legend(loc='best')
ax[0].minorticks_on()
ax[1].plot(90-el_even, ratio1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[1].plot(90-el_odd, ratio2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[1].plot(90-el_even, ratio3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[1].plot(90-el_odd, ratio4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[1].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona')
ax[1].grid( which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].legend(loc='best')
ax[1].minorticks_on()
plt.show()
plt.close(fig)

# %%
meanV1, stdV1, meanV2, stdV2, el = np.loadtxt('MjerenjaLosinj3.txt', delimiter=",",
                                              dtype = 'float', unpack=True,skiprows=4, usecols=[0,1,2,3,5])

v1_310 = meanV1[:-1:2]
v1_320 = meanV1[1:-1:2]
v2_310 = meanV2[1:-1:2]
v2_320 = meanV2[:-1:2]

std_v1_310 = stdV1[:-1:2]
std_v1_320 = stdV1[1:-1:2]
std_v2_310 = stdV2[1:-1:2]
std_v2_320 = stdV2[:-1:2]

ratio1 = v1_310 / v1_320
std_r1 = ratio1 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v1_320**2)/(v1_320**2))
ratio2 = v2_310 / v2_320
std_r2 = ratio2 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v2_320**2)/(v2_320**2))
ratio3 = v1_310 / v2_320
std_r3 = ratio3 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v2_320**2)/(v2_320**2))
ratio4 = v2_310 / v1_320
std_r4 = ratio4 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v1_320**2)/(v1_320**2))

el_even = el[:-1:2]
el_odd = el[1:-1:2]

fig, ax = plt.subplots(2, 1, figsize=(10,10))
ax[0].errorbar(90-el_even, ratio1, std_r1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[0].errorbar(90-el_odd, ratio2, std_r2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[0].errorbar(90-el_even, ratio3, std_r3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[0].errorbar(90-el_odd, ratio4, std_r4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[0].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona',title='Day 3')
ax[0].grid( which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].legend(loc='best')
ax[0].minorticks_on()
ax[1].plot(90-el_even, ratio1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[1].plot(90-el_odd, ratio2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[1].plot(90-el_even, ratio3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[1].plot(90-el_odd, ratio4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[1].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona')
ax[1].grid( which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].legend(loc='best')
ax[1].minorticks_on()
plt.show()
plt.close(fig)

# %%
meanV1, stdV1, meanV2, stdV2, el = np.loadtxt('MjerenjaLosinj4.txt', delimiter=",",
                                              dtype = 'float', unpack=True,skiprows=2, usecols=[0,1,2,3,5])

v1_310 = meanV1[:-1:2]
v1_320 = meanV1[1:-1:2]
v2_310 = meanV2[1:-1:2]
v2_320 = meanV2[:-1:2]

std_v1_310 = stdV1[:-1:2]
std_v1_320 = stdV1[1:-1:2]
std_v2_310 = stdV2[1:-1:2]
std_v2_320 = stdV2[:-1:2]

ratio1 = v1_310 / v1_320
std_r1 = ratio1 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v1_320**2)/(v1_320**2))
ratio2 = v2_310 / v2_320
std_r2 = ratio2 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v2_320**2)/(v2_320**2))
ratio3 = v1_310 / v2_320
std_r3 = ratio3 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v2_320**2)/(v2_320**2))
ratio4 = v2_310 / v1_320
std_r4 = ratio4 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v1_320**2)/(v1_320**2))

el_even = el[:-1:2]
el_odd = el[1:-1:2]

fig, ax = plt.subplots(2, 1, figsize=(10,10))
ax[0].errorbar(90-el_even, ratio1, std_r1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[0].errorbar(90-el_odd, ratio2, std_r2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[0].errorbar(90-el_even, ratio3, std_r3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[0].errorbar(90-el_odd, ratio4, std_r4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[0].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona',title='Day 4')
ax[0].grid( which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].legend(loc='best')
ax[0].minorticks_on()
ax[1].plot(90-el_even, ratio1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[1].plot(90-el_odd, ratio2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[1].plot(90-el_even, ratio3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[1].plot(90-el_odd, ratio4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[1].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona')
ax[1].grid( which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].legend(loc='best')
ax[1].minorticks_on()
plt.show()
plt.close(fig)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import lfilter, remez
from scipy.constants import c
from scipy.constants import pi
from scipy import stats
from scipy import signal
from scipy import integrate
from scipy import interpolate
from astropy.io import ascii
import math as m

# %%
### --- IMPORT extraterrestrial SUNSHINE 
exterre = ascii.read("Spctrm_0.dat")
wvlgth = exterre['Wvlgth']
exterre = exterre['Gueymard_2003']
exterre = exterre[:181]
wvlgth = wvlgth[:181]/10.0

### --- IMPORT UDARNOG PRESJEKA OZONA provided by SMARTS at 228 K 
###     (ne Gorshelev koji sam koristio na završnom)
abs_O3UV = ascii.read("Abs_O3UV.dat")
Wvl_full = abs_O3UV['Wvl_nm']
Wvl_nm = Wvl_full[:341]
cross_sec_full = abs_O3UV['Ref_228K']
cross_sec = cross_sec_full[:181]

# NO2 absorption cross-section 
dataloc = 'No2_280h.dat'
# wl [nm], wn [cm-1], crossec [cm2/molec], crossecErr [cm2/molec]
dataNO2 = pd.read_csv(dataloc,delim_whitespace=True, skiprows=41,skipinitialspace=True, names = ["wl","wn","crossec","crossecErr"])

# INTERPOLACIJA udarnih presjeka za NO2 za wvlgth array
# tablica je po padajućim valnim duljinama (počine na 800 nm i ide do 250nm),
# pa ju treba flip prije nego što se radi interpolacija 
crossNO2 = np.interp(wvlgth, np.flip(dataNO2.wl), np.flip(dataNO2.crossec), left=None, right=None, period=None)

fig, ax = plt.subplots(figsize=(8,5))
ax.plot(wvlgth , cross_sec, label='ozon',ls='--')
ax.scatter(dataNO2.wl , dataNO2.crossec, label='originalni NO2')
ax.plot(wvlgth , crossNO2, label='interpolirani NO2')
ax.set(xlim=(300,340))
ax.set(xlabel='$\lambda$ (nm)', ylabel='Apsorpcijski udarni presjek [cm$^2$/molekuli]')
ax.axvline(wvlgth[60], color='red', linestyle='--', lw=2)
ax.axvline(wvlgth[80], color='red', linestyle='--', lw=2)
ax.grid()
ax.set_yscale('log')
ax.legend(loc='best')
plt.show()
plt.close(fig)
# Out:
# C:\Users\kstepancic\AppData\Local\Temp\ipykernel_34916\744585001.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataNO2 = pd.read_csv(dataloc,delim_whitespace=True, skiprows=41,skipinitialspace=True, names = ["wl","wn","crossec","crossecErr"])

# %%
 # all SZA in degrees, relative optical air mass has no units
def air_mass_o(SZA): 
    a1_o = 2.6845e2        # air-mass ozone
    a2_o = 0.5
    a3_o = 115.420
    a4_o = -3.2922
    return (np.cos(np.deg2rad(SZA)) + a1_o*SZA**a2_o * (a3_o-SZA)**a4_o)**-1

def air_mass_R(SZA): 
    a1_r = 4.5665e-1       # air-mass Rayleigh scattering
    a2_r = 0.07
    a3_r = 96.4836
    a4_r = -1.6970
    return (np.cos(np.deg2rad(SZA)) + a1_r*SZA**a2_r * (a3_r-SZA)**a4_r)**-1

def air_mass_a(SZA): 
    a1_ae = 3.1141e-2      # air-mass aerosol scattering, also used for NO2
    a2_ae = 0.1
    a3_ae = 92.4710
    a4_ae = -1.3814
    return (np.cos(np.deg2rad(SZA)) + a1_ae*SZA**a2_ae * (a3_ae-SZA)**a4_ae)**-1

fig, ax = plt.subplots(figsize=(8,5))

zeniths = np.linspace(0,80,50) # iznad 80 ide do velikih vrijednosti
ax.plot(zeniths, air_mass_o(zeniths), label='ozon',ls='--')
ax.plot(zeniths, air_mass_R(zeniths), label='Rayleigh',ls='--')
ax.plot(zeniths, air_mass_a(zeniths), label='aerosol',ls='--')
ax.plot(zeniths, 1/np.cos(np.deg2rad(zeniths)), label='nominalni 1/cos',color='gray')
ax.set(xlabel='Zenitni kut [deg]', ylabel='Relativna zračna masa (rel. airmass)')

ax.grid()
ax.legend(loc='best')
plt.show()
plt.close(fig)

# %%
p0 = 1013.3

#---------------- Apsorpcija na ozonu    
# 1 DU = 0.001 atm-cm, so 0.3 atm-cm = 300 DU.
def tau_o(wvlgth,DU):
    return 2.687e16*cross_sec*DU

# -------------- Rayleighovo raspršenje
def tau_R(wvlgth):
    a1 = 117.2594*1e-12  # 117   microm^(-4)        # SMARTS calculation
    a2 = -1.3215*1e-6    # -1.32 microm^(-2)
    a3 = 3.2073e-4       # 3.2073e-4
    a4 = -7.6842e-5*1e6  # -7.68 microm^(2)
    return 1/(a1*(wvlgth)**4 + a2*(wvlgth)**2 + a3 + a4*(wvlgth)**(-2))

# -------------- Raspršenje na aerosolima -- promijenjeno na urbani
def tau_a(wvlgth):  
    alfa1 = 0.827 # urban, 50% humidity
    alfa2 = 1.171 # urban, 50% humidity
    tau_a5 = 0.3442 # SMARTS2 value
    ang_beta = tau_a5/(2**alfa2)  
    beta1 = 2**(alfa2-alfa1)*ang_beta
    lam1 = 1000 #nm 
    return beta1*(wvlgth/lam1)**(-alfa1)
    
#---------------- Apsorpcija na NO2 --ovdje se malo pogađalo, ali se dobije konzistentno
# u gradovima median 0.00166 atm-cm, raspon je 4.4e-5 do 0.013 atm-cm 
def tau_n(wvlgth,duN):
    return 2.687e16*crossNO2*duN

# Vraća zračenje Sunca nakon prolaska kroz atmosferu za zadani zenitni kut (stupnjevi)
# i stupac ozona u DU, može mu se zadati i stupac NO2 u atm-cm jedinicama, 
# pretpostavljena je niska vrijednost

def atmosphere(SZA, psite, DU, duN=1.66):
    ## RELATIVNe OPTIČKe ZRAČNe MASe
    am_o = air_mass_o(SZA)
    am_R = air_mass_R(SZA)
    am_a = air_mass_a(SZA)
    
    #-------------- Rayleighovo raspršenje
    P = psite/p0
    rayleigh = P*tau_R(wvlgth)*am_R   
    #---------------- Apsorpcija na ozonu
    ozone = tau_o(wvlgth,DU)*am_o
    #-------------- Raspršenje na aerosolima
    aerosol = tau_a(wvlgth)*am_a
    # ------------- Apsorpcija na NO2, use aerosol airmass
    no2 = tau_n(wvlgth,duN)*am_a
    
    #SURF_IRR = [x*np.exp(-y*am_o-z*am_R-k*am_a) for x,y,z,k in zip(exterre,ozone,ray,aerosol)]
    SURF_IRR = exterre*np.exp(-ozone-rayleigh-aerosol-no2) 
    return SURF_IRR

# %%
### --- spektri propusnosti filtera i osjetljivosti detektora očitani u WebPlotDigitizer-u
S = 0.06e-6 # aktivna površina 0.06 mm^2

wv1, H1 = np.loadtxt('BP310.csv', delimiter=",", dtype = 'float', unpack=True)
wv2, H2 = np.loadtxt('BP320.csv', delimiter=",", dtype = 'float', unpack=True)
wvr, responsivity = np.loadtxt('responsivity.csv', delimiter=",", dtype = 'float', unpack=True)
R = responsivity * 0.160
wv = wvr # provjereno -- sve su valne duljine iste wv1, wv2, wvr

detector1 = R * H1    # sensor * 310nm filter
detector2 = R * H2    # sensor * 320nm filter

print("integral za detektor 1 =",integrate.simpson(detector1,x=wvlgth), "[A/W]")
print("integral za detektor 2 =",integrate.simpson(detector2,x=wvlgth),"[A/W]")
# Out:
# integral za detektor 1 = 0.770199577902841 [A/W]
# integral za detektor 2 = 0.8944136474418795 [A/W]

# %%
#####~~~~~~~~~~ MJERENJA LOŠINJ DAN 3 ~~~~~~~~~~#####

SZA = np.arange(20,81,1)
DU = np.arange(200,601,10)

meanV1, stdV1, meanV2, stdV2, el = np.loadtxt('MjerenjaLosinj3.txt', delimiter=",",
                                              dtype = 'float', unpack=True,skiprows=4, usecols=[0,1,2,3,5])

psite=29.82*33.86389 # inHg to hPa
I1 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector1,x=wvlgth) for sza in SZA] for du in DU])
I2 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector2,x=wvlgth) for sza in SZA] for du in DU])
RATIO = I1/I2

v1_310 = meanV1[:-1:2]
v1_320 = meanV1[1:-1:2]
v2_310 = meanV2[1:-1:2]
v2_320 = meanV2[:-1:2]

std_v1_310 = stdV1[:-1:2]
std_v1_320 = stdV1[1:-1:2]
std_v2_310 = stdV2[1:-1:2]
std_v2_320 = stdV2[:-1:2]

ratio1 = v1_310 / v1_320
std_r1 = ratio1 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v1_320**2)/(v1_320**2))
ratio2 = v2_310 / v2_320
std_r2 = ratio2 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v2_320**2)/(v2_320**2))
ratio3 = v1_310 / v2_320
std_r3 = ratio3 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v2_320**2)/(v2_320**2))
ratio4 = v2_310 / v1_320
std_r4 = ratio4 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v1_320**2)/(v1_320**2))

el_even = el[:-1:2]
el_odd = el[1:-1:2]

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(90-el_even, ratio1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Ratio one')
ax.plot(90-el_odd, ratio2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Ratio two')
#ax.plot(90-el_even, ratio3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
#ax.plot(90-el_odd, ratio4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1 sa zamjenom filtera')
ax.plot(SZA, RATIO[24], linestyle=':', label="{} DU".format(DU[24]))
ax.plot(SZA, RATIO[25], linestyle='-.', label="{} DU".format(DU[25]))
ax.plot(SZA, RATIO[26], linestyle='-', label="{} DU".format(DU[26]))
ax.plot(SZA, RATIO[27], linestyle='--', label="{} DU".format(DU[27]))
ax.set(ylim=(0.22,0.32), xlim=(30,45))
ax.set(xlabel='Solar Zenith Angle', ylabel='Voltage ratio',title='Day 3')
ax.grid( which='major', color='#666666', linestyle='-')
ax.grid(which='minor', color='silver', linestyle='--')
ax.legend(loc='best')
ax.minorticks_on()
plt.show()
plt.close(fig)

# %%
#####~~~~~~~~~~ MJERENJA LOŠINJ DAN 4 ~~~~~~~~~~#####

SZA = np.arange(20,81,1)
DU = np.arange(200,601,10)

meanV1, stdV1, meanV2, stdV2, el = np.loadtxt('MjerenjaLosinj4.txt', delimiter=",",
                                              dtype = 'float', unpack=True,skiprows=2, usecols=[0,1,2,3,5])

psite=29.99*33.86389 # inHg to hPa
I1 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector1,x=wvlgth) for sza in SZA] for du in DU])
I2 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector2,x=wvlgth) for sza in SZA] for du in DU])
RATIO = I1/I2

v1_310 = meanV1[:-1:2]
v1_320 = meanV1[1:-1:2]
v2_310 = meanV2[1:-1:2]
v2_320 = meanV2[:-1:2]

std_v1_310 = stdV1[:-1:2]
std_v1_320 = stdV1[1:-1:2]
std_v2_310 = stdV2[1:-1:2]
std_v2_320 = stdV2[:-1:2]

ratio1 = v1_310 / v1_320
std_r1 = ratio1 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v1_320**2)/(v1_320**2))
ratio2 = v2_310 / v2_320
std_r2 = ratio2 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v2_320**2)/(v2_320**2))
ratio3 = v1_310 / v2_320
std_r3 = ratio3 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v2_320**2)/(v2_320**2))
ratio4 = v2_310 / v1_320
std_r4 = ratio4 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v1_320**2)/(v1_320**2))

el_even = el[:-1:2]
el_odd = el[1:-1:2]

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(90-el_even, ratio1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Ratio one')
ax.plot(90-el_odd, ratio2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Ratio two')
#ax.plot(90-el_even, ratio3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2)')
#ax.plot(90-el_odd, ratio4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax.plot(SZA, RATIO[25], linestyle=':', label="{} DU".format(DU[25]))
ax.plot(SZA, RATIO[26], linestyle='-.', label="{} DU".format(DU[26]))
ax.plot(SZA, RATIO[27], linestyle='-', label="{} DU".format(DU[27]))
ax.plot(SZA, RATIO[28], linestyle='--', label="{} DU".format(DU[28]))
ax.set(ylim=(0.26,0.32), xlim=(30,38))
ax.set(xlabel='Solar Zenith Angle', ylabel='Voltage ratio',title='Day 4')
ax.grid( which='major', color='#666666', linestyle='-')
ax.grid(which='minor', color='silver', linestyle='--')
ax.legend(loc='best')
ax.minorticks_on()
plt.show()
plt.close(fig)

# %%
#####~~~~~~~~~~ MJERENJA AD SCOPY UREĐAJEM - 12.7.2024. ~~~~~~~~~~#####

meanV2, stdV2, meanV1, stdV1, z = np.loadtxt('MjerenjaScopy.csv', delimiter=";",
                                              dtype = 'float', unpack=True,skiprows=2, usecols=[0,1,2,3,5])

fig, ax = plt.subplots(figsize=(10,5))
ax.errorbar(z, meanV1,stdV1, ls='None',marker='o', markersize=5., alpha = 0.6, label='Napon na izlazu prvog kanala')
ax.errorbar(z, meanV2,stdV2, ls='None',marker='o', markersize=5., alpha = 0.6, label='Napon na izlazu drugog kanala')
ax.set(xlabel='Elevacija', ylabel='Napon [V]',title='Koncar -IET')
ax.grid( which='major', color='#666666', linestyle='-')
ax.grid(which='minor', color='silver', linestyle='--')
ax.legend(loc='best')
ax.minorticks_on()
plt.show()
plt.close(fig)

# %%
SZA = np.arange(20,81,1)
DU = np.arange(200,601,10)

meanV2, stdV2, meanV1, stdV1, z = np.loadtxt('MjerenjaScopy.csv', delimiter=";",
                                              dtype = 'float', unpack=True,skiprows=2, usecols=[0,1,2,3,5])

psite=29.96*33.86389 # inHg to hPa
I1 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector1,x=wvlgth) for sza in SZA] for du in DU])
I2 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector2,x=wvlgth) for sza in SZA] for du in DU])
RATIO = I1/I2

v1_310 = meanV1[::2]
v1_320 = meanV1[1::2]
v2_310 = meanV2[1::2]
v2_320 = meanV2[::2]

std_v1_310 = stdV1[::2]
std_v1_320 = stdV1[1::2]
std_v2_310 = stdV2[1::2]
std_v2_320 = stdV2[::2]

ratio1 = v1_310 / v1_320
std_r1 = ratio1 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v1_320**2)/(v1_320**2))
ratio2 = v2_310 / v2_320
std_r2 = ratio2 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v2_320**2)/(v2_320**2))
ratio3 = v1_310 / v2_320
std_r3 = ratio3 * np.sqrt((std_v1_310**2)/(v1_310**2) + (std_v2_320**2)/(v2_320**2))
ratio4 = v2_310 / v1_320
std_r4 = ratio4 * np.sqrt((std_v2_310**2)/(v2_310**2) + (std_v1_320**2)/(v1_320**2))

z_even = z[::2]
z_odd = z[1::2]

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(z_even, ratio1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Ratio one')
ax.plot(z_odd, ratio2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Raatio two')
#ax.plot(z_even, ratio3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2')
#ax.plot(z_odd, ratio4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax.plot(SZA, RATIO[21], linestyle=':', label="{} DU".format(DU[21]))
ax.plot(SZA, RATIO[22], linestyle='-.', label="{} DU".format(DU[22]))
ax.plot(SZA, RATIO[23], linestyle='-', label="{} DU".format(DU[23]))
ax.plot(SZA, RATIO[24], linestyle='--', label="{} DU".format(DU[24]))
ax.plot(SZA, RATIO[25], linestyle=':', label="{} DU".format(DU[25]))
ax.plot(SZA, RATIO[26], linestyle='-.', label="{} DU".format(DU[26]))
ax.plot(SZA, RATIO[27], linestyle='-', label="{} DU".format(DU[27]))
ax.plot(SZA, RATIO[28], linestyle='--', label="{} DU".format(DU[28]))
ax.set(ylim=(0.26,0.32), xlim=(30,40))
ax.set(xlabel='Solar Zenith Angle', ylabel='Voltage ratio',title='Koncar IET')
ax.grid( which='major', color='#666666', linestyle='-')
ax.grid(which='minor', color='silver', linestyle='--')
ax.legend(loc='best')
ax.minorticks_on()
plt.show()
plt.close(fig)

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt

R1 = 24.9e3
R2 = 8.2e3
C = 0.22e-6

f0= 1/(2*m.pi*C*14.3e3) # R=14k3, C=0.22u Wien bridge resonance
phase1 = m.degrees(-m.atan(2*m.pi*f0*R1*C)) # R=24k9, C=0.22u
shift1 = m.degrees(-m.atan(2*m.pi*f0*(R1+500)*C))
phase2 = m.degrees(m.atan(1/(2*m.pi*f0*R2*C))) # R=8k2, C=0.22u
shift2 = m.degrees(m.atan(1/(2*m.pi*f0*(R2+150)*C)))

print("Frekvencija oscilacija:", f0, "\nFaza 1 =", phase1, " Fazna promjena:", phase1-shift1,
      "\nFaza 2 = ", phase2,"  Fazna promjena:", phase2-shift2)

D = np.linspace(1, 1023, 1023)
#Rwa = (1024-D)/1024*20e3
Rwb = 35+D/1024*20e3
Rpwb = 1/(1/Rwb + 1/150)

R_val = np.array([80.31, 84.27, 88.22, 92.16, 96.09, 100, 103.9, 107.79, 111.67, 115.54, 119.4, 123.24, 127.08, 130.9, 134.71,
                138.51, 142.29, 146.07])
Rpotx = 1/(1/R_val - 1/150)

fig, ax = plt.subplots(2, 1, figsize=(10,10))
ax[0].plot(Rwb, Rpwb,ls='None', marker='o', color='blue', markersize=5., alpha=0.2)
ax[0].scatter(Rpotx, R_val, marker='o', color='orange', label='Simulirani otpori PT100 senzora')
ax[0].set(xlabel='Otpor potenciomentra', ylabel='Otpor paralele',title='Koncar - IET')
ax[0].set(xlim=(0,6000))
ax[0].grid(which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].minorticks_on()
ax[0].legend(loc='best')
ax[1].plot(Rwb, Rpwb,ls='None', marker='o', color='blue', markersize=5., alpha=0.5)
ax[1].scatter(Rpotx, R_val, marker='o', color='orange', label='Simulirani otpori PT100 senzora')
ax[1].set(xlabel='Otpor potenciometra', ylabel='Otpor paralele')
ax[1].set(xlim=(0,1000))
ax[1].grid(which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].minorticks_on()
ax[1].legend(loc='best')
plt.show()
plt.close(fig)

print("DigiPot:\n", Rpotx, "Ω\n\nPT100sim:\n", R_val, "Ω")
# Out:
# Frekvencija oscilacija: 50.58961954605701
# Faza 1 = -60.131369911651326  Fazna promjena: 0.4894615663591111
# Faza 2 =  60.16889487121334   Fazna promjena: 0.45023782735479045
# DigiPot:
#  [ 172.85837279  192.30944774  214.19553253  239.00414938  267.36227045
#   300.          338.06941432  383.04904051  437.00756588  502.93093442
#   585.29411765  690.80717489  831.67539267 1028.0104712  1321.5500327
#  1808.22454308 2768.28793774 5575.19083969] Ω
#
# PT100sim:
#  [ 80.31  84.27  88.22  92.16  96.09 100.   103.9  107.79 111.67 115.54
#  119.4  123.24 127.08 130.9  134.71 138.51 142.29 146.07] Ω

# %%
def interp_resist_to_temp_np(resist):
    import numpy as np
    return np.interp(resist, resistance_vals, temperature_vals)

def interp_resist_to_temp_naive(resist):
    if resist < resistance_vals[0] or resist > resistance_vals[-1]: raise ValueError("Value out of range")
    i = 0
    while resist > resistance_vals[i+1]:
        i += 1
    delta_r = resistance_vals[i+1] - resistance_vals[i]
    delta_t = 1.0
    cur_dr = resist - resistance_vals[i]
    temp = temperature_vals[i] + cur_dr/delta_r
    return temp

temperature_vals = list(range(-200, 850+1))
resistance_vals = [ # 18.52 Ohm correspond to a temperature of -200 deg C
     18.52, 18.96, 19.39, 19.82, 20.25, 20.68, 21.11, 21.54, 21.97, 22.40, 
     22.83, 23.26, 23.69, 24.12, 24.55, 24.97, 25.39, 25.82, 26.25, 26.67, 
     27.10, 27.52, 27.95, 28.37, 28.80, 29.22, 29.65, 30.07, 30.49, 30.92, 
     31.34, 31.76, 32.18, 32.61, 33.03, 33.45, 33.86, 34.28, 34.70, 35.12, 
     35.54, 35.96, 36.38, 36.80, 37.22, 37.63, 38.05, 38.47, 38.89, 39.31, 
     39.72, 40.14, 40.56, 40.97, 41.39, 41.80, 42.22, 42.64, 43.05, 43.46, 
     43.88, 44.29, 44.71, 45.12, 45.53, 45.95, 46.35, 46.76, 47.18, 47.59, 
     48.00, 48.41, 48.82, 49.23, 49.64, 50.06, 50.47, 50.88, 51.29, 51.70, 
     52.11, 52.52, 52.92, 53.33, 53.74, 54.15, 54.56, 54.97, 55.38, 55.78, 
     56.19, 56.60, 57.00, 57.41, 57.82, 58.22, 58.63, 59.04, 59.44, 59.85, 
     60.26, 60.67, 61.07, 61.48, 61.87, 62.29, 62.69, 63.10, 63.50, 63.91, 
     64.30, 64.70, 65.11, 65.51, 65.91, 66.31, 66.72, 67.12, 67.52, 67.92, 
     68.33, 68.73, 69.13, 69.53, 69.93, 70.33, 70.73, 71.13, 71.53, 71.93, 
     72.33, 72.73, 73.13, 73.53, 73.93, 74.33, 74.73, 75.13, 75.53, 75.93, 
     76.33, 76.73, 77.13, 77.52, 77.92, 78.32, 78.72, 79.11, 79.51, 79.91, 
     80.31, 80.70, 81.10, 81.50, 81.89, 82.29, 82.69, 83.08, 83.48, 83.88, 
     84.27, 84.67, 85.06, 85.46, 85.85, 86.25, 86.64, 87.04, 87.43, 87.83, 
     88.22, 88.62, 89.01, 89.40, 89.80, 90.19, 90.59, 90.98, 91.37, 91.77, 
     92.16, 92.55, 92.95, 93.34, 93.73, 94.12, 94.52, 94.91, 95.30, 95.69, 
     96.09, 96.48, 96.87, 97.26, 97.65, 98.04, 98.44, 98.83, 99.22, 99.61, 
    100.00,100.39,100.78,101.17,101.56,101.95,102.34,102.73,103.12,103.51,
    103.90,104.29,104.68,105.07,105.46,105.85,106.24,106.63,107.02,107.40,
    107.79,108.18,108.57,108.96,109.35,109.73,110.12,110.51,110.90,111.28,
    111.67,112.06,112.45,112.83,113.22,113.61,113.99,114.38,114.77,115.15,
    115.54,115.93,116.31,116.70,117.08,117.47,117.85,118.24,118.62,119.01,
    119.40,119.78,120.16,120.55,120.93,121.32,121.70,122.09,122.47,122.86,
    123.24,123.62,124.01,124.39,124.77,125.17,125.55,125.93,126.32,126.70,
    127.08,127.46,127.85,128.23,128.61,128.99,129.38,129.76,130.14,130.52,
    130.90,131.28,131.67,132.05,132.43,132.81,133.19,133.57,133.95,134.33,
    134.71,135.09,135.47,135.85,136.23,136.61,136.99,137.37,137.75,138.13,
    138.51,138.89,139.27,139.65,140.03,140.39,140.77,141.15,141.53,141.91,
    142.29,142.66,143.04,143.42,143.80,144.18,144.56,144.94,145.32,145.69,
    146.07,146.45,146.82,147.20,147.58,147.95,148.33,148.71,149.08,149.46,
    149.83,150.21,150.58,150.96,151.34,151.71,152.09,152.46,152.84,153.21,
    153.58,153.95,154.32,154.71,155.08,155.46,155.83,156.21,156.58,156.96,
    157.33,157.71,158.08,158.45,158.83,159.20,159.56,159.94,160.31,160.68,
    161.05,161.43,161.80,162.17,162.54,162.91,163.28,163.66,164.03,164.40,
    164.77,165.14,165.51,165.88,166.25,166.62,167.00,167.37,167.74,168.11,
    168.48,168.85,169.22,169.59,169.96,170.33,170.69,171.06,171.43,171.80,
    172.17,172.54,172.91,173.27,173.64,174.01,174.39,174.75,175.12,175.49,
    175.86,176.23,176.59,176.96,177.33,177.70,178.06,178.43,178.80,179.16,
    179.53,179.90,180.26,180.63,180.99,181.36,181.73,182.09,182.46,182.82,
    183.19,183.55,183.92,184.28,184.65,185.01,185.38,185.74,186.11,186.47,
    186.84,187.20,187.56,187.93,188.29,188.65,189.02,189.38,189.74,190.11,
    190.47,190.83,191.20,191.56,191.92,192.28,192.66,193.02,193.38,193.74,
    194.10,194.47,194.83,195.19,195.55,195.90,196.26,196.62,196.98,197.35,
    197.71,198.07,198.43,198.79,199.15,199.51,199.87,200.23,200.59,200.95,
    201.31,201.67,202.03,202.38,202.74,203.10,203.46,203.82,204.18,204.54,
    204.90,205.25,205.61,205.97,206.33,206.70,207.05,207.41,207.77,208.13,
    208.48,208.84,209.20,209.55,209.91,210.27,210.62,210.98,211.34,211.69,
    212.05,212.40,212.76,213.12,213.47,213.83,214.19,214.55,214.90,215.26,
    215.61,215.97,216.32,216.68,217.03,217.39,217.73,218.08,218.44,218.79,
    219.15,219.50,219.85,220.21,220.56,220.91,221.27,221.62,221.97,222.32,
    222.68,223.03,223.38,223.73,224.09,224.45,224.80,225.15,225.50,225.85,
    226.21,226.56,226.91,227.26,227.61,227.96,228.31,228.66,229.01,229.36,
    229.72,230.07,230.42,230.77,231.12,231.47,231.81,232.16,232.51,232.86,
    233.21,233.56,233.91,234.26,234.60,234.95,235.30,235.65,236.00,236.35,
    236.70,237.05,237.40,237.75,238.09,238.44,238.79,239.14,239.48,239.83,
    240.18,240.52,240.87,241.22,241.56,241.91,242.25,242.60,242.95,243.29,
    243.64,243.98,244.33,244.67,245.02,245.36,245.71,246.05,246.40,246.74,
    247.09,247.43,247.78,248.12,248.46,248.81,249.15,249.50,249.84,250.18,
    250.53,250.89,251.21,251.55,251.90,252.24,252.59,252.94,253.28,253.62,
    253.96,254.30,254.65,254.99,255.33,255.67,256.01,256.35,256.70,257.04,
    257.38,257.72,258.06,258.40,258.74,259.08,259.42,259.76,260.10,260.44,
    260.78,261.12,261.46,261.80,262.14,262.48,262.83,263.17,263.50,263.84,
    264.18,264.52,264.86,265.20,265.54,265.87,266.21,266.55,266.89,267.22,
    267.56,267.90,268.24,268.57,268.91,269.25,269.58,269.92,270.26,270.59,
    270.93,271.27,271.60,271.94,272.27,272.61,272.95,273.28,273.62,273.95,
    274.29,274.62,274.96,275.29,275.63,275.96,276.31,276.64,276.97,277.31,
    277.64,277.98,278.31,278.64,278.98,279.31,279.64,279.98,280.31,280.64,
    280.98,281.31,281.64,281.97,282.31,282.64,282.97,283.30,283.63,283.97,
    284.30,284.63,284.96,285.29,285.62,285.95,286.30,286.63,286.96,287.29,
    287.62,287.95,288.28,288.61,288.94,289.27,289.60,289.93,290.26,290.59,
    290.92,291.25,291.58,291.90,292.23,292.56,292.90,293.23,293.56,293.89,
    294.21,294.54,294.87,295.20,295.53,295.85,296.18,296.51,296.84,297.16,
    297.49,297.82,298.14,298.47,298.80,299.12,299.45,299.78,300.10,300.43,
    300.75,301.08,301.41,301.73,302.06,302.38,302.71,303.03,303.36,303.68,
    304.01,304.33,304.66,304.98,305.30,305.63,305.95,306.28,306.60,306.92,
    307.25,307.57,307.89,308.22,308.54,308.86,309.19,309.51,309.83,310.15,
    310.48,310.80,311.12,311.45,311.78,312.10,312.43,312.75,313.07,313.39,
    313.71,314.04,314.36,314.68,315.00,315.32,315.64,315.96,316.28,316.60,
    316.92,317.24,317.56,317.88,318.20,318.52,318.85,319.17,319.49,319.81,
    320.12,320.44,320.76,321.08,321.40,321.72,322.03,322.34,322.66,322.98,
    323.30,323.61,323.93,324.25,324.57,324.88,325.21,325.53,325.85,326.16,
    326.48,326.79,327.11,327.43,327.74,328.06,328.38,328.69,329.01,329.32,
    329.64,329.95,330.27,330.58,330.90,331.21,331.53,331.84,332.16,332.47,
    332.79,333.10,333.41,333.73,334.04,334.36,334.68,334.99,335.31,335.62,
    335.93,336.25,336.56,336.87,337.18,337.50,337.81,338.12,338.43,338.75,
    339.06,339.37,339.68,339.99,340.30,340.62,340.94,341.25,341.55,341.87,
    342.18,342.49,342.80,343.11,343.42,343.73,344.04,344.35,344.66,344.97,
    345.28,345.59,345.90,346.21,346.52,346.83,347.15,347.46,347.76,348.07,
    348.38,348.69,349.00,349.31,349.61,349.92,350.23,350.54,350.85,351.15,
    351.46,351.77,352.07,352.38,352.69,352.99,353.30,353.61,353.91,354.22,
    354.53,354.83,355.14,355.44,355.75,356.06,356.37,356.68,356.98,357.29,
    357.59,357.90,358.20,358.51,358.81,359.12,359.42,359.72,360.03,360.33,
    360.64,360.94,361.24,361.55,361.85,362.15,362.46,362.76,363.06,363.36,
    363.67,363.97,364.27,364.57,364.88,365.18,365.49,365.79,366.09,366.40,
    366.70,367.00,367.30,367.60,367.90,368.20,368.50,368.81,369.11,369.41,
    369.71,370.01,370.31,370.61,370.91,371.21,371.52,371.82,372.12,372.41,
    372.71,373.01,373.31,373.61,373.91,374.21,374.51,374.80,375.10,375.40,
    375.70,376.00,376.29,376.59,376.89,377.19,377.49,377.79,378.09,378.39,
    378.68,378.98,379.28,379.57,379.87,380.17,380.46,380.76,381.05,381.35,
    381.65,381.94,382.24,382.53,382.83,383.12,383.42,383.71,384.01,384.30,
    384.60,384.89,385.18,385.48,385.77,386.07,386.37,386.66,386.96,387.25,
    387.55,387.84,388.13,388.42,388.72,389.01,389.31,389.61,389.90,390.19,
    390.48] # 390.48 Ohm Pt100 resistance at 850 deg C

# %%
from itertools import combinations

def series_resistance_combinations(resistors):
    possible_resistances = set()

    # Iterate over all possible combinations of resistors (including the empty set)
    for r in range(len(resistors) + 1):
        for combo in combinations(resistors, r):
            possible_resistances.add(sum(combo))
    
    # Return the list of all possible resistances
    return sorted(possible_resistances)

# Example usage
resistors = np.array([0.5, 1, 2, 2+2, 8.06, 16, 33])
result = series_resistance_combinations(resistors)
#print("All possible series resistance values:", result)
#print("All possible series resistance values:", 80 + np.asarray(result))
resistors = 80 + resistors
temp_res = interp_resist_to_temp_np(resistors)
temp_def = np.arange(-200,800,10)
A = 3.9083e-3
B = -5.775e-7
resistors_def = 100*(1 + A*temp_def + B*temp_def**2)
resistors_lin = 100*(1 + A*temp_def)
temp_lin = (80+np.asarray(result)-100)/(A*100)
temp_val = interp_resist_to_temp_np(resistance_vals)
#print("\nTemperature: ", temp_lin)
temp = interp_resist_to_temp_np(80+np.asarray(result))

fig, ax = plt.subplots(2, 1, figsize=(10,12))
ax[0].plot(resistance_vals, temp_val, ls='--',markersize=5., alpha = 0.6, label='PT100 karakteristika skriptom')
ax[1].plot(resistance_vals, temp_val, ls='--',markersize=5., alpha = 0.6, label='PT100 karakteristika skriptom')
#ax[0].plot(resistors_def, temp_def, ls='-',markersize=5., alpha = 0.6, label='PT100 karakteristika formulom')
#ax[1].plot(resistors_def, temp_def, ls='-',markersize=5., alpha = 0.6, label='PT100 karakteristika formulom')
ax[1].plot(resistors_lin, temp_def, ls='-',markersize=5., alpha = 0.6, label='PT100 linearna aproksimacija')
ax[1].plot(80+np.asarray(result), temp_lin, ls='None', marker='o', markersize=5., alpha = 0.6, label='PT100 izabrani otpornici, linearna aproks')
ax[0].plot(80+np.asarray(result), temp, ls='None', marker='v', markersize=5., alpha = 0.6, label='PT100 izabrani otpornici, skripta')

ax[0].set(xlabel='Otpor [Ω]', ylabel='Temperatura [°C]',title='PT-100 simulator', xlim =(70,150), ylim=(-60, 120))
ax[1].set(xlabel='Otpor [Ω]', ylabel='Temperatura [°C]',title='', xlim =(70,150), ylim=(-60, 120))

ax[0].grid( which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].legend(loc='best')
ax[0].minorticks_on()
ax[1].grid( which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].legend(loc='best')
ax[1].minorticks_on()
plt.show()
fig.savefig('pt-100.png')
plt.close(fig)

# %%
r_values = np.loadtxt('DATA_20250210_152639.csv', dtype = 'float', unpack=True)
A = 3.9083e-3
B = -5.775e-7
temp_lin = (r_values-100)/(A*100)

fig, ax = plt.subplots(1, 1, figsize=(10,6))

ax.plot(resistors_lin, temp_def, ls='-',markersize=5., alpha = 0.6, label='PT100 linearna aproksimacija')
ax.plot(r_values, temp_lin, ls='None', marker='v', markersize=5., alpha = 0.6, label='PT100 mjerenje, linearna aproks')

ax.set(xlabel='Otpor [Ω]', ylabel='Temperatura [°C]',title='PT-100 simulator', xlim =(80,147), ylim=(-60, 120))

ax.grid( which='major', color='#666666', linestyle='-')
ax.grid(which='minor', color='silver', linestyle='--')
ax.legend(loc='best')
ax.minorticks_on()
plt.show()
#fig.savefig('pt-100.png')
plt.close(fig)

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from astropy.io import ascii

meanV1_3, stdV1_3, meanV2_3, stdV2_3, el_3 = np.loadtxt('MjerenjaLosinj3.txt', delimiter=",",
                                                  dtype = 'float', unpack=True,skiprows=4, usecols=[0,1,2,3,5])

#el_3 = el_3[np.where(el_3<60)]
#meanV1_3 = meanV1_3[np.where(el_3<60)]
#meanV2_3 = meanV2_3[np.where(el_3<60)]

meanV1_4, stdV1_4, meanV2_4, stdV2_4, el_4 = np.loadtxt('MjerenjaLosinj4.txt', delimiter=",",
                                                  dtype = 'float', unpack=True,skiprows=2, usecols=[0,1,2,3,5])

v1_310_3 = meanV1_3[:-1:2]
v1_320_3 = meanV1_3[1:-1:2]
v2_310_3 = meanV2_3[1:-1:2]
v2_320_3 = meanV2_3[:-1:2]

ratio1_3 = v1_310_3 / v1_320_3
ratio2_3 = v2_310_3 / v2_320_3
ratio3_3 = v1_310_3 / v2_320_3
ratio4_3 = v2_310_3 / v1_320_3

el_even_3 = el_3[:-1:2]
el_odd_3 = el_3[1:-1:2]

v1_310_4 = meanV1_4[:-1:2]
v1_320_4 = meanV1_4[1:-1:2]
v2_310_4 = meanV2_4[1:-1:2]
v2_320_4 = meanV2_4[:-1:2]

ratio1_4 = v1_310_4 / v1_320_4
ratio2_4 = v2_310_4 / v2_320_4
ratio3_4 = v1_310_4 / v2_320_4
ratio4_4 = v2_310_4 / v1_320_4

el_even_4 = el_4[:-1:2]
el_odd_4 = el_4[1:-1:2]

fig, ax = plt.subplots(2, 1, figsize=(10,12))
ax[0].plot(el_3, meanV1_3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu prvog kanala')
ax[0].plot(el_3, meanV2_3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu drugog kanala')
ax[0].set(xlabel='Zenitna udaljenost', ylabel='Napon [V]', title='Mali Lošinj - 4.7.2024.')
ax[0].grid( which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].legend(loc='best')
ax[0].minorticks_on()
ax[1].plot(el_4, meanV1_4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu prvog kanala')
ax[1].plot(el_4, meanV2_4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Napon na izlazu drugog kanala')
ax[1].set(xlabel='Zenitna udaljenost', ylabel='Napon [V]', title='Mali Lošinj - 5.7.2024.')
ax[1].grid( which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].legend(loc='best')
ax[1].minorticks_on()
plt.show()
plt.close(fig)

fig, ax = plt.subplots(2, 1, figsize=(10,12))
ax[0].plot(90-el_even_3[np.where(el_even_3<60)], ratio1_3[np.where(el_even_3<60)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[0].plot(90-el_odd_3[np.where(el_odd_3<60)], ratio2_3[np.where(el_odd_3<60)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[0].plot(90-el_even_3[np.where(el_even_3<60)], ratio3_3[np.where(el_even_3<60)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[0].plot(90-el_odd_3[np.where(el_odd_3<60)], ratio4_3[np.where(el_odd_3<60)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[0].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona', title='Mali Lošinj - 4.7.2024.')
ax[0].grid( which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].legend(loc='best')
ax[0].minorticks_on()
ax[1].plot(90-el_even_4[np.where(el_even_4>55)], ratio1_4[np.where(el_even_4>55)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[1].plot(90-el_odd_4[np.where(el_odd_4>55)], ratio2_4[np.where(el_odd_4>55)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[1].plot(90-el_even_4[np.where(el_even_4>55)], ratio3_4[np.where(el_even_4>55)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2 (kao na diplomskom)')
ax[1].plot(90-el_odd_4[np.where(el_odd_4>55)], ratio4_4[np.where(el_odd_4>55)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
ax[1].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona', title='Mali Lošinj - 5.7.2024.')
ax[1].grid( which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].legend(loc='best')
ax[1].minorticks_on()
plt.show()
plt.close(fig)

print("{0:0.3f}, {1:0.3f}".format(np.mean(ratio1_3[np.where(el_even_3<60)]/ratio2_3[np.where(el_even_3<60)]), np.std(ratio1_3[np.where(el_even_3<60)]/ratio2_3[np.where(el_even_3<60)])))
print("{0:0.3f}, {1:0.3f}".format(np.mean(ratio1_4[np.where(el_even_4>55)]/ratio2_4[np.where(el_even_4>55)]), np.std(ratio1_4[np.where(el_even_4>55)]/ratio2_4[np.where(el_even_4>55)])))
# Out:
# 0.996, 0.014
# 0.983, 0.016

# %%
#####~~~~~~~~~~ MJERENJA AD SCOPY UREĐAJEM - 12.7.2024. ~~~~~~~~~~#####

meanV2, stdV2, meanV1, stdV1, z = np.loadtxt('MjerenjaScopy.csv', delimiter=";",
                                              dtype = 'float', unpack=True,skiprows=2, usecols=[0,1,2,3,5])

v1_310 = meanV1[::2]
v1_320 = meanV1[1::2]
v2_310 = meanV2[1::2]
v2_320 = meanV2[::2]

std_v1_310 = stdV1[::2]
std_v1_320 = stdV1[1::2]
std_v2_310 = stdV2[1::2]
std_v2_320 = stdV2[::2]

ratio1 = v1_310 / v1_320
ratio2 = v2_310 / v2_320
ratio3 = v1_310 / v2_320
ratio4 = v2_310 / v1_320

z_even = z[::2]
z_odd = z[1::2]

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(z, meanV1, ls='None',marker='o', markersize=5., alpha = 0.6, label='Napon na izlazu prvog kanala')
ax.plot(z, meanV2, ls='None',marker='o', markersize=5., alpha = 0.6, label='Napon na izlazu drugog kanala')
ax.set(xlabel='Elevacija', ylabel='Napon [V]',title='Koncar-IET - MJERENJA AD SCOPY UREĐAJEM - 12.7.2024.')
ax.grid( which='major', color='#666666', linestyle='-')
ax.grid(which='minor', color='silver', linestyle='--')
ax.legend(loc='best')
ax.minorticks_on()
plt.show()
plt.close(fig)

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(z_even, ratio1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax.plot(z_odd, ratio2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax.plot(z_even, ratio3, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 1/2')
ax.plot(z_odd, ratio4, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer kanala 2/1')
#ax.set(ylim=(0.26,0.32), xlim=(30,40))
ax.set(xlabel='Zenitna udaljenost', ylabel='Omjer napona',title='Koncar IET')
ax.grid( which='major', color='#666666', linestyle='-')
ax.grid(which='minor', color='silver', linestyle='--')
ax.legend(loc='best')
ax.minorticks_on()
plt.show()
plt.close(fig)

print("{0:0.3f}, {1:0.3f}".format(np.mean(ratio1/ratio2), np.std(ratio1/ratio2)))
# Out:
# 0.994, 0.014

# %%
SZA = np.arange(20,81,1)
DU = np.arange(200,601,10)
psite=29.83*33.86389 # inHg to hPa

I1 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector1,x=wvlgth) for sza in SZA] for du in DU])
I2 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector2,x=wvlgth) for sza in SZA] for du in DU])
RATIO = I1/I2

fig, ax = plt.subplots(2, 1, figsize=(10,12))
ax[0].plot(90-el_even_3[np.where(el_even_3<60)], ratio1_3[np.where(el_even_3<60)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[0].plot(90-el_odd_3[np.where(el_odd_3<60)], ratio2_3[np.where(el_odd_3<60)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[0].plot(SZA, RATIO[24], linestyle=':', label="{} DU".format(DU[24]))
ax[0].plot(SZA, RATIO[25], linestyle='-.', label="{} DU".format(DU[25]))
ax[0].plot(SZA, RATIO[26], linestyle='-', label="{} DU".format(DU[26]))
ax[0].plot(SZA, RATIO[27], linestyle='--', label="{} DU".format(DU[27]))
ax[0].set(ylim=(0.22,0.32), xlim=(30,45))
ax[0].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona',title='Mali Lošinj - 4.7.2024.')
ax[0].grid( which='major', color='#666666', linestyle='-')
ax[0].grid(which='minor', color='silver', linestyle='--')
ax[0].legend(loc='best')
ax[0].minorticks_on()

psite=29.99*33.86389 # inHg to hPa

I1 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector1,x=wvlgth) for sza in SZA] for du in DU])
I2 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector2,x=wvlgth) for sza in SZA] for du in DU])
RATIO = I1/I2

ax[1].plot(90-el_even_4[np.where(el_even_4>55)], ratio1_4[np.where(el_even_4>55)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax[1].plot(90-el_odd_4[np.where(el_odd_4>55)], ratio2_4[np.where(el_odd_4>55)], ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax[1].plot(SZA, RATIO[25], linestyle=':', label="{} DU".format(DU[25]))
ax[1].plot(SZA, RATIO[26], linestyle='-.', label="{} DU".format(DU[26]))
ax[1].plot(SZA, RATIO[27], linestyle='-', label="{} DU".format(DU[27]))
ax[1].plot(SZA, RATIO[28], linestyle='--', label="{} DU".format(DU[28]))
ax[1].set(ylim=(0.26,0.32), xlim=(30,38))
ax[1].set(xlabel='Zenitna udaljenost', ylabel='Omjer napona',title='Mali Lošinj - 5.7.2024.')
ax[1].grid( which='major', color='#666666', linestyle='-')
ax[1].grid(which='minor', color='silver', linestyle='--')
ax[1].legend(loc='best')
ax[1].minorticks_on()
plt.show()
plt.close(fig)

# %%
SZA = np.arange(20,81,1)
DU = np.arange(200,601,10)
psite=29.96*33.86389 # inHg to hPa

I1 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector1,x=wvlgth) for sza in SZA] for du in DU])
I2 = np.array([[integrate.simpson(atmosphere(sza,psite,du,1.66)*detector2,x=wvlgth) for sza in SZA] for du in DU])
RATIO = I1/I2

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(z_even, ratio1, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na prvom kanalu')
ax.plot(z_odd, ratio2, ls='None',marker='o',markersize=5., alpha = 0.6, label='Omjer na drugom kanalu')
ax.plot(SZA, RATIO[21], linestyle=':', label="{} DU".format(DU[21]))
ax.plot(SZA, RATIO[22], linestyle='-.', label="{} DU".format(DU[22]))
ax.plot(SZA, RATIO[23], linestyle='-', label="{} DU".format(DU[23]))
ax.plot(SZA, RATIO[24], linestyle='--', label="{} DU".format(DU[24]))
ax.plot(SZA, RATIO[25], linestyle=':', label="{} DU".format(DU[25]))
ax.plot(SZA, RATIO[26], linestyle='-.', label="{} DU".format(DU[26]))
ax.plot(SZA, RATIO[27], linestyle='-', label="{} DU".format(DU[27]))
ax.plot(SZA, RATIO[28], linestyle='--', label="{} DU".format(DU[28]))
ax.set(ylim=(0.26,0.32), xlim=(30,40))
ax.set(xlabel='Zenitna udaljenost', ylabel='Omjer napona',title='Koncar-IET')
ax.grid( which='major', color='#666666', linestyle='-')
ax.grid(which='minor', color='silver', linestyle='--')
ax.legend(loc='best')
ax.minorticks_on()
plt.show()
plt.close(fig)

# %%
fig, ax = plt.subplots(2, 1, figsize=(10,11))
ax[0].hist(ratio1_3[np.where(el_even_3<60)]/ratio2_3[np.where(el_even_3<60)])
ax[0].grid()
ax[1].hist(ratio1_4[np.where(el_even_4>55)]/ratio2_4[np.where(el_even_4>55)])
ax[1].grid()
plt.show()
plt.close(fig)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.hist(ratio1/ratio2)
ax.grid()
plt.show()
plt.close(fig)
